# %% [markdown]
# # Transfer Learning Tutorial

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.datasets as datasets
import torchvision.transforms as transforms

# This mounts your google drive storage to this code
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import os
# ----> 2 import torch
#       3 import torch.nn as nn
#       4 import torch.optim as optim
#
# ModuleNotFoundError: No module named 'torch'

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")

root = '/content/gdrive/My Drive/Test/'
# Out:
# Using cuda device

# %% [markdown]
# First, Let's classify "STL10" dataset **without** transfer learning

# %%
# DATA LOAD (STL10 Dataset)

# settings for data normalization
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
    # transforms.Resize((96,96))
])


train_data = datasets.STL10(
    root=root, 
    split='train',
    download=True, 
    transform=transform)

test_data = datasets.STL10(
    root=root,
    split='test',
    download=True, 
    transform=transform)


batch_size = 32
train_loader = torch.utils.data.DataLoader(train_data,batch_size=batch_size,shuffle=True)
test_loader = torch.utils.data.DataLoader(test_data,batch_size=batch_size,shuffle=False)


classes = ('airplane', 'bird', 'car', 'cat',
           'deer', 'dog', 'horse', 'monkey', 'ship', 'truck')


print('Training Data:', len(train_data), 'Test Data', len(test_data))
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Training Data: 5000 Test Data 8000

# %%
# visualize some data
import matplotlib.pyplot as plt
import numpy as np

# functions to show an image


images, labels = next(iter(train_loader))   



sample_index = np.random.choice(batch_size, size=12)     # take 12 random sample index
num_samples = sample_index.size

random_samples = images[sample_index].cpu().numpy()

plt.figure(figsize=(12, 12))

# display test samples
for k in range(num_samples):
    plt.subplot(4, 4, k + 1)
    plt.imshow(random_samples[k].reshape(3,96, 96).transpose(1,2,0)/2 + 0.5)
    plt.title("Class: " + str( classes[labels[sample_index[k]].item()])  )
    plt.axis('off')

    
plt.show()

# %%
# define the CNN: 
# two convolution layers followed by two linear layers

class MyConvNet(nn.Module):   # nn.Module should be inherited for the neural network configuration so that it can work with backpropagation APIs
    def __init__(self):    # define layers: two conv layers and two linear (fully connected) layers 
        super(MyConvNet, self).__init__()
        self.conv_layers = nn.Sequential(
            nn.Conv2d(3, 32, 5),
            nn.ReLU(),
            nn.MaxPool2d(2,2),
            nn.Conv2d(32, 64, 5),
            nn.ReLU(),
            nn.MaxPool2d(2,2),
            nn.Flatten(),
            nn.Linear(21*21*64, 512),
            nn.Linear(512, 10)
        )

        # weight initialization
        for m in self.modules():
            if isinstance(m, nn.Conv2d) or isinstance(m, nn.Linear):
                nn.init.kaiming_normal_(m.weight.data)      # He normalization

    # network connection: two conv layers, each followed by relu and max-pooling with (2x2) kernel, and two linear layer
    def forward(self, x):
        logits = self.conv_layers(x)
        return(logits)


# generate neural net model
model = MyConvNet().to(device)
print(model)
# Out:
# MyConvNet(
#   (conv_layers): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1))
#     (4): ReLU()
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Flatten(start_dim=1, end_dim=-1)
#     (7): Linear(in_features=28224, out_features=512, bias=True)
#     (8): Linear(in_features=512, out_features=10, bias=True)
#   )
# )

# %%
# optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)
optimizer = optim.Adam(model.parameters(), lr=1e-3)

criterion = nn.CrossEntropyLoss()

# %%
# training and test

# epoch: 10
# data dimension: batch_size x Channels x Height x Width (NCHW)
for epoch in range(10):
    # training phase
    # model.train()
    current_loss= 0.0
    for batch_num, (x, target) in enumerate(train_loader):
        x, target = x.to(device), target.to(device)   

        out = model(x)                
        loss = criterion(out,target) 

        optimizer.zero_grad()        
        loss.backward()               
        optimizer.step()              
        current_loss += loss          
        
        # display the training loss in every 100 batches
        if (batch_num+1)%100 == 0 or (batch_num+1)%100 == len(train_loader):
            print('epoch: %d, batch_num: %d, current_loss: %.3f' %(epoch, batch_num+1, current_loss/100))
            current_loss = 0.0
    
    
    # test phase
    with torch.no_grad():   
        # model.eval()        
        total_samples = 0.0
        correct_samples = 0.0
        for (x, target) in test_loader:
            x, target = x.to(device), target.to(device)
            out = model(x)              
            pred = torch.argmax(out,1)  
            correct_samples += (pred == target).sum() 
        print('Accuracy: %.3f' %(100*float(correct_samples) / float(len(test_data))))
# Out:
# epoch: 0, batch_num: 100, current_loss: 5.298
# Accuracy: 10.050
# epoch: 1, batch_num: 100, current_loss: 2.304
# Accuracy: 10.037
# epoch: 2, batch_num: 100, current_loss: 2.304
# Accuracy: 10.125
# epoch: 3, batch_num: 100, current_loss: 2.226
# Accuracy: 22.413
# epoch: 4, batch_num: 100, current_loss: 1.943
# Accuracy: 27.288
# epoch: 5, batch_num: 100, current_loss: 1.780
# Accuracy: 25.212
# epoch: 6, batch_num: 100, current_loss: 1.563
# Accuracy: 28.650
# epoch: 7, batch_num: 100, current_loss: 1.423
# Accuracy: 26.188
# epoch: 8, batch_num: 100, current_loss: 1.324
# Accuracy: 31.300
# epoch: 9, batch_num: 100, current_loss: 1.085
# Accuracy: 31.337

# %%
# Display Some test results 
import numpy as np 
import matplotlib.pyplot as plt


# take one batch of the data
test_data, test_labels = next(iter(test_loader))   

# if cuda_available:
test_data, test_labels = test_data.to(device), test_labels.to(device)
out = model(test_data)              # put the test data to the trained network
pred = torch.argmax(out,1)          # prediction to the highest probability 


sample_index = np.random.choice(batch_size, size=12)     # take 12 random sample index
num_samples = sample_index.size

random_samples = test_data[sample_index].cpu().numpy()

plt.figure(figsize=(12, 12))

# display test samples
for k in range(num_samples):
    plt.subplot(4, 4, k + 1)
    plt.imshow(random_samples[k].reshape(3,96, 96).transpose(1,2,0)/2 + 0.5)
    plt.title("True: " + str( classes[test_labels[sample_index[k]].item()]) + ",\nPred: " + str(classes[pred[sample_index[k]].item()]))
    plt.axis('off')

    
plt.show()

# %% [markdown]
# # Now, Let's try **Transfer Learning**

# %% [markdown]
# 1. Pre-train the network with cifar-10 dataset
# 2. fine-tune with STL10 dataset

# %%
# DATA LOAD (cifar-10 dataset)

# settings for data normalization
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
    transforms.Resize((96,96))
])


train_data = datasets.CIFAR10(
    root=root, 
    train=True,
    download=True, 
    transform=transform)

test_data = datasets.CIFAR10(
    root=root,
    train=False,
    download=True, 
    transform=transform)


batch_size = 32
train_loader = torch.utils.data.DataLoader(train_data,batch_size=batch_size,shuffle=True)
test_loader = torch.utils.data.DataLoader(test_data,batch_size=batch_size,shuffle=False)


classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

print('Training Data:', len(train_data), 'Test Data', len(test_data))
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Training Data: 50000 Test Data 10000

# %%
# generate neural net model
model = MyConvNet().to(device)
print(model)

# Optimizer
optimizer = optim.Adam(model.parameters(), lr=1e-3)

# Loss Function
criterion = nn.CrossEntropyLoss()
# Out:
# MyConvNet(
#   (conv_layers): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1))
#     (4): ReLU()
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Flatten(start_dim=1, end_dim=-1)
#     (7): Linear(in_features=28224, out_features=512, bias=True)
#     (8): Linear(in_features=512, out_features=10, bias=True)
#   )
# )

# %%
# training and test

# epoch: 5
# data dimension: batch_size x Channels x Height x Width (NCHW)
for epoch in range(5):
    # training phase
    # model.train()
    current_loss= 0.0
    for batch_num, (x, target) in enumerate(train_loader):
        x, target = x.to(device), target.to(device)   

        out = model(x)                
        loss = criterion(out,target) 

        optimizer.zero_grad()        
        loss.backward()               
        optimizer.step()              
        current_loss += loss          
        
        # display the training loss in every 100 batches
        if (batch_num+1)%100 == 0 or (batch_num+1)%100 == len(train_loader):
            print('epoch: %d, batch_num: %d, current_loss: %.3f' %(epoch, batch_num+1, current_loss/100))
            current_loss = 0.0
    
    
    # test phase
    with torch.no_grad():   
        # model.eval()        
        total_samples = 0.0
        correct_samples = 0.0
        for (x, target) in test_loader:
            x, target = x.to(device), target.to(device)
            out = model(x)              
            pred = torch.argmax(out,1)  
            correct_samples += (pred == target).sum() 
        print('Accuracy: %.3f' %(100*float(correct_samples) / float(len(test_data))))
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# epoch: 0, batch_num: 100, current_loss: 4.476
# epoch: 0, batch_num: 200, current_loss: 2.006
# epoch: 0, batch_num: 300, current_loss: 1.919
# epoch: 0, batch_num: 400, current_loss: 1.917
# epoch: 0, batch_num: 500, current_loss: 1.848
# epoch: 0, batch_num: 600, current_loss: 1.805
# epoch: 0, batch_num: 700, current_loss: 1.777
# epoch: 0, batch_num: 800, current_loss: 1.753
# epoch: 0, batch_num: 900, current_loss: 1.718
# epoch: 0, batch_num: 1000, current_loss: 1.695
# epoch: 0, batch_num: 1100, current_loss: 1.675
# epoch: 0, batch_num: 1200, current_loss: 1.659
# epoch: 0, batch_num: 1300, current_loss: 1.638
# epoch: 0, batch_num: 1400, current_loss: 1.566
# epoch: 0, batch_num: 1500, current_loss: 1.607
# Accuracy: 43.680
# epoch: 1, batch_num: 100, current_loss: 1.515
# epoch: 1, batch_num: 200, current_loss: 1.495
# epoch: 1, batch_num: 300, current_loss: 1.487
# epoch: 1, batch_num: 400, current_loss: 1.422
# epoch: 1, batch_num: 500, current_loss: 1.377
# epoch: 1, batch_num: 600, current_loss: 1.348
# epoch: 1, batch_num: 700, current_loss: 1.357
# epoch: 1, batch_num: 800, current_loss: 1.316
# epoch: 1, batch_num: 900, current_loss: 1.308
# epoch: 1, batch_num: 1000, current_loss: 1.301
# epoch: 1, batch_num: 1100, current_loss: 1.294
# epoch: 1, batch_num: 1200, current_loss: 1.278
# epoch: 1, batch_num: 1300, current_loss: 1.259
# epoch: 1, batch_num: 1400, current_loss: 1.202
# epoch: 1, batch_num: 1500, current_loss: 1.218
# Accuracy: 55.280
# epoch: 2, batch_num: 100, current_loss: 1.077
# epoch: 2, batch_num: 200, current_loss: 1.078
# epoch: 2, batch_num: 300, current_loss: 1.086
# epoch: 2, batch_num: 400, current_loss: 1.046
# epoch: 2, batch_num: 500, current_loss: 1.114
# epoch: 2, batch_num: 600, current_loss: 1.080
# epoch: 2, batch_num: 700, current_loss: 1.160
# epoch: 2, batch_num: 800, current_loss: 1.111
# epoch: 2, batch_num: 900, current_loss: 1.079
# epoch: 2, batch_num: 1000, current_loss: 1.163
# epoch: 2, batch_num: 1100, current_loss: 1.074
# epoch: 2, batch_num: 1200, current_loss: 1.082
# epoch: 2, batch_num: 1300, current_loss: 1.114
# epoch: 2, batch_num: 1400, current_loss: 1.119
# epoch: 2, batch_num: 1500, current_loss: 1.062
# Accuracy: 60.520
# epoch: 3, batch_num: 100, current_loss: 0.885
# epoch: 3, batch_num: 200, current_loss: 0.904
# epoch: 3, batch_num: 300, current_loss: 0.895
# epoch: 3, batch_num: 400, current_loss: 0.904
# epoch: 3, batch_num: 500, current_loss: 0.969
# epoch: 3, batch_num: 600, current_loss: 0.950
# epoch: 3, batch_num: 700, current_loss: 0.918
# epoch: 3, batch_num: 800, current_loss: 0.974
# epoch: 3, batch_num: 900, current_loss: 0.944
# epoch: 3, batch_num: 1000, current_loss: 0.959
# epoch: 3, batch_num: 1100, current_loss: 0.961
# epoch: 3, batch_num: 1200, current_loss: 0.977
# epoch: 3, batch_num: 1300, current_loss: 0.969
# epoch: 3, batch_num: 1400, current_loss: 0.961
# epoch: 3, batch_num: 1500, current_loss: 0.971
# Accuracy: 61.060
# epoch: 4, batch_num: 100, current_loss: 0.738
# epoch: 4, batch_num: 200, current_loss: 0.700
# epoch: 4, batch_num: 300, current_loss: 0.714
# epoch: 4, batch_num: 400, current_loss: 0.761
# epoch: 4, batch_num: 500, current_loss: 0.784
# epoch: 4, batch_num: 600, current_loss: 0.815
# epoch: 4, batch_num: 700, current_loss: 0.780
# epoch: 4, batch_num: 800, current_loss: 0.828
# epoch: 4, batch_num: 900, current_loss: 0.838
# epoch: 4, batch_num: 1000, current_loss: 0.828
# epoch: 4, batch_num: 1100, current_loss: 0.854
# epoch: 4, batch_num: 1200, current_loss: 0.833
# epoch: 4, batch_num: 1300, current_loss: 0.867
# epoch: 4, batch_num: 1400, current_loss: 0.772
# epoch: 4, batch_num: 1500, current_loss: 0.888
# Accuracy: 61.390

# %% [markdown]
# Pre-training is done!
#
# Now, Let's fine-tune with STL10 dataset

# %%
print(model)
# Out:
# MyConvNet(
#   (conv_layers): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1))
#     (4): ReLU()
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Flatten(start_dim=1, end_dim=-1)
#     (7): Linear(in_features=28224, out_features=512, bias=True)
#     (8): Linear(in_features=512, out_features=10, bias=True)
#   )
# )

# %%
# Replace the last few layers


# # model.conv_layers[7] = nn.Linear(21*21*64, 128).to(device)   
model.conv_layers[8] = nn.Linear(512, 10).to(device)       # Replace Last layer

# %%
# Load STL10 data again

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
    # transforms.Resize((96,96))
])

train_data = datasets.STL10(
    root=root, 
    split='train',
    download=True, 
    transform=transform)

test_data = datasets.STL10(
    root=root,
    split='test',
    download=True, 
    transform=transform)


batch_size = 32
train_loader = torch.utils.data.DataLoader(train_data,batch_size=batch_size,shuffle=True)
test_loader = torch.utils.data.DataLoader(test_data,batch_size=batch_size,shuffle=False)


classes = ('airplane', 'bird', 'car', 'cat',
           'deer', 'dog', 'horse', 'monkey', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# Optimizer
optimizer = optim.Adam(model.parameters(), lr=1e-4)

# Loss Function
criterion = nn.CrossEntropyLoss()

# %%
# training and test

# epoch: 5
# data dimension: batch_size x Channels x Height x Width (NCHW)
for epoch in range(5):
    # training phase
    # model.train()
    current_loss= 0.0
    for batch_num, (x, target) in enumerate(train_loader):
        x, target = x.to(device), target.to(device)   

        out = model(x)                
        loss = criterion(out,target) 

        optimizer.zero_grad()        
        loss.backward()               
        optimizer.step()              
        current_loss += loss          
        
        # display the training loss in every 100 batches
        if (batch_num+1)%100 == 0 or (batch_num+1)%100 == len(train_loader):
            print('epoch: %d, batch_num: %d, current_loss: %.3f' %(epoch, batch_num+1, current_loss/100))
            current_loss = 0.0
    
    
    # test phase
    with torch.no_grad():   
        # model.eval()        
        total_samples = 0.0
        correct_samples = 0.0
        for (x, target) in test_loader:
            x, target = x.to(device), target.to(device)
            out = model(x)              
            pred = torch.argmax(out,1)  
            correct_samples += (pred == target).sum() 
        print('Accuracy: %.3f' %(100*float(correct_samples) / float(len(test_data))))
# Out:
# epoch: 0, batch_num: 100, current_loss: 1.890
# Accuracy: 52.625
# epoch: 1, batch_num: 100, current_loss: 1.024
# Accuracy: 58.638
# epoch: 2, batch_num: 100, current_loss: 0.613
# Accuracy: 60.138
# epoch: 3, batch_num: 100, current_loss: 0.330
# Accuracy: 60.962
# epoch: 4, batch_num: 100, current_loss: 0.151
# Accuracy: 61.300
